# %%
import pandas as pd

# %%
pd.DataFrame._repr_html_??

# %%
bikes = pd.read_csv('data/bikes.csv')

# %%
bikes
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 0          7147  Subscriber    Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1          7524  Subscriber    Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2         10927  Subscriber    Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3         12907  Subscriber    Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4         13168  Subscriber    Male  2013-07-01 11:16:00  2013-07-01 11:18:00
# 5         13595  Subscriber    Male  2013-07-01 12:37:00  2013-07-01 12:48:00
# 6         18880  Subscriber    Male  2013-07-02 17:47:00  2013-07-02 17:56:00
# 7         19689  Subscriber    Male  2013-07-03 09:07:00  2013-07-03 09:16:00
# 8         21028  Subscriber    Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 9         23558  Subscriber  Female  2013-07-04 15:00:00  2013-07-04 15:16:00
# 10        24383  Subscriber    Male  2013-07-04 17:17:00  2013-07-04 17:42:00
# ...

# %%
def show(self, n):
    from IPython.display import display
    with pd.option_context('display.max_rows', n):
        display(self.iloc[:n])

pd.DataFrame.show = show

# %%
pd.option_context??

# %%
bikes.show(100)
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 0      7147  Subscriber    Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1      7524  Subscriber    Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2     10927  Subscriber    Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3     12907  Subscriber    Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4     13168  Subscriber    Male  2013-07-01 11:16:00  2013-07-01 11:18:00
# 5     13595  Subscriber    Male  2013-07-01 12:37:00  2013-07-01 12:48:00
# 6     18880  Subscriber    Male  2013-07-02 17:47:00  2013-07-02 17:56:00
# 7     19689  Subscriber    Male  2013-07-03 09:07:00  2013-07-03 09:16:00
# 8     21028  Subscriber    Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 9     23558  Subscriber  Female  2013-07-04 15:00:00  2013-07-04 15:16:00
# 10    24383  Subscriber    Male  2013-07-04 17:17:00  2013-07-04 17:42:00
# 11    24673  Subscriber    Male  2013-07-04 18:13:00  2013-07-04 18:42:00
# ...

# %% [markdown]
# id amount date
# 1 5000 2018-08-17
# 1 2000 2018-10-11
# 2 1200 2018-01-17
# 2 3400 2018-02-11

# %%
df = pd.read_clipboard()

# %%
df['date'] = df['date'].astype('datetime64[ns]')

# %%
df
# Out:
#    id  amount       date
# 0   1    5000 2018-08-17
# 1   1    2000 2018-10-11
# 2   2    1200 2018-01-17
# 3   2    3400 2018-02-11

# %%
df.groupby('id').resample('M', on='date')['amount'].sum()
# Out:
# id  date
# 1   2018-01-31    5000
#     2018-02-28    2000
# 2   2018-08-31    1200
#     2018-09-30       0
#     2018-10-31    3400
# Name: amount, dtype: int64

# %%
df1 = df.set_index('date')
df1.groupby('id').resample('M')['amount'].sum()
# Out:
# id  date
# 1   2018-08-31    5000
#     2018-09-30       0
#     2018-10-31    2000
# 2   2018-01-31    1200
#     2018-02-28    3400
# Name: amount, dtype: int64

# %%
# Out:
# id  date
# 1   2018-08-31    5000
#     2018-09-30       0
#     2018-10-31    2000
# 2   2018-01-31    1200
#     2018-02-28    3400
# Name: amount, dtype: int64

# %%
df.groupby('cl_id').resample('30D')['amount_sum'].sum()
# Out:
# cl_id  date
# 1      2018-08-17    5000
#        2018-09-16    2000
#        2018-10-16       0
#        2018-11-15    2300
# 2      2018-01-17    4600
#        2018-02-16    2000
#        2018-03-18    1500
# Name: amount_sum, dtype: int64

# %%
df.groupby('cl_id').first() - df.groupby('cl_id').last()
# Out:
#        amount_sum
# cl_id
# 1            2700
# 2            -300

# %%
df1 = df[df['cl_id'] == 1]
df1
# Out:
#    cl_id  amount_sum       date
# 0      1        5000 2018-08-17
# 1      1        2000 2018-10-11
# 2      1        2300 2018-11-15

# %%
df1.resample('30D', on='date')['amount_sum'].sum()
# Out:
# date
# 2018-08-17    5000
# 2018-09-16    2000
# 2018-10-16       0
# 2018-11-15    2300
# Freq: 30D, Name: amount_sum, dtype: int64
